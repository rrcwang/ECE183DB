# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
import skimage
import skimage.transform

disc_ecc_ratio = 1.2630053228734255

# %%
image = cv.imread('get_angle/x0_z0.png',0)

plt.imshow(img,cmap = 'gray')
edges = cv.Canny(img,100,200)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-33-a577168d80d9> in <module>()
#       2 img = skimage.transform.resize(image, (image.shape[0], image.shape[1]),anti_aliasing=False)
#       3 plt.imshow(img,cmap = 'gray')
# ----> 4 edges = cv.Canny(img,0,1)
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\canny.cpp:829: error: (-215:Assertion failed) _src.depth() == CV_8U in function 'cv::Canny'

# %%
plt.figure(figsize=(20,10))
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
boundary = np.argwhere(edges != 0)
disc_bounds = cv.fitEllipse(boundary)

# %%
xy_ratio = disc_bounds[1][1]/disc_bounds[1][0]
print(xy_ratio)
# Out:
# 1.2630053228734255
